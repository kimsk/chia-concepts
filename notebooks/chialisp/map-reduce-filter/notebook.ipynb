# %% [markdown]
# ## map
# [map.clsp](./map.clsp)

# %%
with open('./map.clsp', 'r') as file:
    clsp = file.read()

print_clsp(clsp)

map_puzzle: Program = load_program("./map.clsp", [])
print_program(map_puzzle)
# Out:
#    1 (mod (FN . input_list)
#    2     (defun rec (FN lst)
#    3         (if lst
#    4             (c
#    5                 (a FN (f lst))
#    6                 (rec FN (r lst))
#    7             )
#    8             ()
#    9         )
#   10     )
#   11     (rec FN input_list)
#   12 )
# (a (q 2 2 (c 2 (c 5 (c 7 ())))) (c (q 2 (i 11 (q 4 (a 5 19) (a 2 (c 2 (c 5 (c 27 ()))))) ()) 1) 1))

# %%
map_triple = map_puzzle.curry(
    Program.to(assemble("(+ 1 1 1)"))
)

print_program(map_triple)

lst = Program.to([42, 72, 37, 53])
result = map_triple.run(lst)
print_program(result)
# Out:
# (a (q 2 (q 2 2 (c 2 (c 5 (c 7 ())))) (c (q 2 (i 11 (q 4 (a 5 19) (a 2 (c 2 (c 5 (c 27 ()))))) ()) 1) 1)) (c (q 16 1
# 1 1) 1))
# (126 216 111 159)

# %%
map_square = map_puzzle.curry(
    Program.to(assemble("(* 1 1)"))
)

print_program(map_square)

lst = Program.to([42, 72, 37, 53])
result = map_square.run(lst)
print_program(result)
# Out:
# (a (q 2 (q 2 2 (c 2 (c 5 (c 7 ())))) (c (q 2 (i 11 (q 4 (a 5 19) (a 2 (c 2 (c 5 (c 27 ()))))) ()) 1) 1)) (c (q 18 1
# 1) 1))
# (1764 5184 1369 2809)

# %% [markdown]
# ## reduce
# [reduce](./reduce.clsp)

# %%
with open('./reduce.clsp', 'r') as file:
    clsp = file.read()

print_clsp(clsp)
reduce_puzzle: Program = load_program("./reduce.clsp", [])
print_program(reduce_puzzle)
# Out:
#    1 ; FN (acc lst)
#    2 (mod (FN . input_list)
#    3     (defun rec (FN acc lst)
#    4         (if lst
#    5             (rec FN
#    6                 (a FN (list acc (f lst)))
#    7                 (r lst)
#    8             )
#    9             acc
#   10         )
#   11     )
#   12     (rec FN
#   13         (f input_list)
#   14         (r input_list)
#   15     )
#   16 )
# (a (q 2 2 (c 2 (c 5 (c 11 (c 15 ()))))) (c (q 2 (i 23 (q 2 2 (c 2 (c 5 (c (a 5 (c 11 (c 39 ()))) (c 55 ()))))) (q .
# 11)) 1) 1))

# %%
reduce_sum = reduce_puzzle.curry(
    Program.to(assemble("(+ 2 5)"))
)

print(disassemble(reduce_sum))

lst = Program.to([1, 2, 3, 4, 5])
result = reduce_sum.run(lst)
print_program(result)
# Out:
# (a (q 2 (q 2 2 (c 2 (c 5 (c 11 (c 15 ()))))) (c (q 2 (i 23 (q 2 2 (c 2 (c 5 (c (a 5 (c 11 (c 39 ()))) (c 55 ())))))
# (q . 11)) 1) 1)) (c (q 16 2 5) 1))
# 15

# %%
reduce_factorial = reduce_puzzle.curry(
    Program.to(assemble("(* 2 5)"))
)
print(disassemble(reduce_factorial))

lst = Program.to([1, 2, 3, 4, 5])
result = reduce_factorial.run(lst)
print_program(result)
# Out:
# (a (q 2 (q 2 2 (c 2 (c 5 (c 11 (c 15 ()))))) (c (q 2 (i 23 (q 2 2 (c 2 (c 5 (c (a 5 (c 11 (c 39 ()))) (c 55 ())))))
# (q . 11)) 1) 1)) (c (q 18 2 5) 1))
# 120

# %% [markdown]
# ## filter
# [filter.clsp](./filter.clsp)

# %%
with open('./filter.clsp', 'r') as file:
    clsp = file.read()

print_clsp(clsp)
filter_puzzle = load_program("./filter.clsp", [])
print_program(filter_puzzle)
# Out:
#    1 (mod (FN . input_list)
#    2     (defun rec (FN acc lst)
#    3         (if lst
#    4             (rec FN
#    5                 (if (a FN (f lst))
#    6                     (c
#    7                         (f lst)
#    8                         acc
#    9                     )
#   10                     acc
#   11                 )
#   12                 (r lst)
#   13             )
#   14             acc
#   15         )
#   16     )
#   17
#   18     (defun rev (acc lst)
#   19         (if lst
#   20             (rev (c (f lst) acc) (r lst))
#   21             acc
#   22         )
#   23     )
#   24
#   25     (rev
#   26         ()
#   27         (rec FN () input_list)
#   28     )
#   29 )
# (a (q 2 6 (c 2 (c () (c (a 4 (c 2 (c 5 (c () (c 7 ()))))) ())))) (c (q (a (i 23 (q 2 4 (c 2 (c 5 (c (a (i (a 5 39)
# (q 4 39 11) (q . 11)) 1) (c 55 ()))))) (q . 11)) 1) 2 (i 11 (q 2 6 (c 2 (c (c 19 5) (c 27 ())))) (q . 5)) 1) 1))

# %%
filter_larger_than_42 = filter_puzzle.curry(
    Program.to(assemble("(> 1 (q . 42))"))
)

lst = Program.to([112, 37, 130, 41, 45])
result = filter_larger_than_42.run(lst)
print_program(result)
# Out:
# (112 130 45)

# %% [markdown]
# ## Chain
# [chain.clsp](./chain.clsp)

# %%
with open('./chain.clsp', 'r') as file:
    clsp = file.read()

print_clsp(clsp)
chain_puzzle = load_program("./chain.clsp", [])
print_program(chain_puzzle)
# Out:
#    1 (mod (Functions . input_list)
#    2     (defun rec (functions input)
#    3         (if functions
#    4             (rec
#    5                 (r functions)
#    6                 (a (f functions) input)
#    7             )
#    8             input
#    9         )
#   10     )
#   11
#   12     (rec
#   13         Functions
#   14         input_list
#   15     )
#   16 )
# (a (q 2 2 (c 2 (c 5 (c 7 ())))) (c (q 2 (i 5 (q 2 2 (c 2 (c 13 (c (a 9 11) ())))) (q . 11)) 1) 1))

# %%
lst = Program.to([112, 37, 130, 41, 45])
print_program(lst)
filtered_lst = filter_larger_than_42.run(lst)
print_program(filtered_lst)
square_lst = map_square.run(filtered_lst) 
print_program(square_lst)
sum_result = reduce_sum.run(square_lst)
print_program(sum_result)
# Out:
# (112 37 130 41 45)
# (112 130 45)
# (12544 16900 2025)
# 31469

# %%
result = chain_puzzle.curry(
    [
        filter_larger_than_42,
        map_square,
        reduce_sum
    ]
).run(Program.to([112, 37, 130, 41, 45]))
print_program(result)
# Out:
# 31469
