# %% [markdown]
# # [Lambda](https://chialisp.com/examples#lambda)
# > Compiles a block of code into a single executable expression. Useful for writing functions as arguments to other functions.
#
# ```clojure
# (lambda (n1 n2)
#     ;; Returns the two added together.
#     (+ n1 n2)
# )
# ```

# %% [markdown]
# ## clib

# %%
clsp = Path("libs.clib").read_text()
print_clsp(clsp)
# Out:
#    1 (
#    2     (defun map (fn lst)
#    3         (if lst
#    4             (c
#    5                 (a fn (f lst))
#    6                 (map fn (r lst))
#    7             )
#    8             ()
#    9         )
#   10     )
#   11
#   12     (defun reduce_ (fn acc lst)
#   13         (if lst
#   14             (reduce_ fn
#   15                 (a fn (list acc (f lst)))
#   16                 (r lst)
#   17             )
#   18             acc
#   19         )
#   20     )
#   21
#   22     (defun reduce (fn lst)
#   23         (reduce_ fn (f lst) (r lst))
#   24     )
#   25
#   26     (defun rev (acc lst)
#   27         (if lst
#   28             (rev (c (f lst) acc) (r lst))
#   29             acc
#   30         )
#   31     )
#   32
#   33     (defun filter_ (fn acc lst)
#   34         (if lst
#   35             (filter_ fn
#   36                 (if (a fn (f lst))
#   37                     (c
#   38                         (f lst)
#   39                         acc
#   40                     )
#   41                     acc
#   42                 )
#   43                 (r lst)
#   44             )
#   45             acc
#   46         )
#   47     )
#   48
#   49     (defun filter (fn input_list)
#   50         (rev
#   51             ()
#   52             (filter_ fn () input_list)
#   53         )
#   54     )
#   55
#   56     (defun chain (functions lst)
#   57         (if functions
#   58             (chain
#   59                 (r functions)
#   60                 (a (f functions) lst)
#   61             )
#   62             lst
#   63         )
#   64     )
#   65 )

# %% [markdown]
# ## map triple

# %%
lst = Program.to([42, 72, 37, 53])

# %%
clsp = """
(mod lst
    (include libs.clib)
    (map (lambda v (+ v v v)) lst)
)
"""
print_clsp(clsp)
program = Program(compile_clvm_text(clsp, search_paths=["."]))
print_program(program)
cost, result = program.run_with_cost(INFINITE_COST, lst)
print(f'cost: {cost}')
print_program(result)
# Out:
#   1
#   2 (mod lst
#   3     (include libs.clib)
#   4     (map (lambda v (+ v v v)) lst)
#   5 )
#   6
# (a (q 2 2 (c 2 (c (q 16 1 1 1) (c 3 ())))) (c (q 2 (i 11 (q 4 (a 5 19) (a 2 (c 2 (c 5 (c 27 ()))))) ()) 1) 1))
# cost: 10031
# (126 216 111 159)

# %% [markdown]
# ## map square

# %%
clsp = """
(mod lst
    (include libs.clib)
    (map (lambda v (* v v)) lst)
)
"""
print_clsp(clsp)
program = Program(compile_clvm_text(clsp, search_paths=["."]))
print_program(program)
cost, result = program.run_with_cost(INFINITE_COST, lst)
print(f'cost: {cost}')
print_program(result)
# Out:
#   1
#   2 (mod lst
#   3     (include libs.clib)
#   4     (map (lambda v (* v v)) lst)
#   5 )
#   6
# (a (q 2 2 (c 2 (c (q 18 1 1) (c 3 ())))) (c (q 2 (i 11 (q 4 (a 5 19) (a 2 (c 2 (c 5 (c 27 ()))))) ()) 1) 1))
# cost: 9559
# (1764 5184 1369 2809)

# %% [markdown]
# ## reduce
# ### factorial

# %%
clsp = """
(mod lst
    (include libs.clib)
    (reduce (lambda (v1 v2) (* v1 v2)) lst)
)
"""
print_clsp(clsp)
program = Program(compile_clvm_text(clsp, search_paths=["."]))
print_program(program)
lst = Program.to([1, 2, 3, 4, 5])
cost, result = program.run_with_cost(INFINITE_COST, lst)
print(f'cost: {cost}')
print_program(result)
# Out:
#   1
#   2 (mod lst
#   3     (include libs.clib)
#   4     (reduce (lambda (v1 v2) (* v1 v2)) lst)
#   5 )
#   6
# (a (q 2 4 (c 2 (c (q 18 2 5) (c 3 ())))) (c (q (a 6 (c 2 (c 5 (c 19 (c 27 ()))))) 2 (i 23 (q 2 6 (c 2 (c 5 (c (a 5
# (c 11 (c 39 ()))) (c 55 ()))))) (q . 11)) 1) 1))
# cost: 10950
# 120

# %% [markdown]
# ## sum

# %%
clsp = """
(mod lst
    (include libs.clib)
    (reduce (lambda (v1 v2) (+ v1 v2)) lst)
)
"""
print_clsp(clsp)
program = Program(compile_clvm_text(clsp, search_paths=["."]))
print_program(program)
lst = Program.to([1, 2, 3, 4, 5])
cost, result = program.run_with_cost(INFINITE_COST, lst)
print(f'cost: {cost}')
print_program(result)
# Out:
#   1
#   2 (mod lst
#   3     (include libs.clib)
#   4     (reduce (lambda (v1 v2) (+ v1 v2)) lst)
#   5 )
#   6
# (a (q 2 4 (c 2 (c (q 16 2 5) (c 3 ())))) (c (q (a 6 (c 2 (c 5 (c 19 (c 27 ()))))) 2 (i 23 (q 2 6 (c 2 (c 5 (c (a 5
# (c 11 (c 39 ()))) (c 55 ()))))) (q . 11)) 1) 1))
# cost: 9974
# 15

# %% [markdown]
# ## filter

# %%
clsp = """
(mod lst
    (include libs.clib)
    (filter (lambda n (> n 42)) lst)
)
"""
print_clsp(clsp)
program = Program(compile_clvm_text(clsp, search_paths=["."]))
print_program(program)
lst = Program.to([112, 37, 130, 41, 45])
cost, result = program.run_with_cost(INFINITE_COST, lst)
print(f'cost: {cost}')
print_program(result)
# Out:
#   1
#   2 (mod lst
#   3     (include libs.clib)
#   4     (filter (lambda n (> n 42)) lst)
#   5 )
#   6
# (a (q 2 4 (c 2 (c (q 21 1 (q . 42)) (c 3 ())))) (c (q (a 14 (c 2 (c () (c (a 10 (c 2 (c 5 (c () (c 11 ())))))
# ())))) (a (i 23 (q 2 10 (c 2 (c 5 (c (a (i (a 5 39) (q 4 39 11) (q . 11)) 1) (c 55 ()))))) (q . 11)) 1) 2 (i 11 (q
# 2 14 (c 2 (c (c 19 5) (c 27 ())))) (q . 5)) 1) 1))
# cost: 14677
# (112 130 45)
