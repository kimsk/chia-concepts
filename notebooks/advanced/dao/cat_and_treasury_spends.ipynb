# %%
cat_tail = load_hex("./cat_tail.hex")
print_program(cat_tail)
print(cat_tail.get_tree_hash())
p, c = cat_tail.uncurry()
print_program(p)
print_program(c)
p.get_tree_hash().hex()
# Out:
# (a (q 2 (q 2 (i 1535 (q 8) (q 2 (i (= 1471 5) () (q 2 (i (= 1471 (a 22 (c 2 (c (c 23 (c 22527 47)) (c (a 26 (c 2 (c
# 95 (c 11 (c (c 23 (c 22527 47)) (c 10239 ())))))) ()))))) () (q 8)) 1)) 1)) 1) (c (q ((a . 4) 1 1 . 2) ((a (i 5 (q
# 2 18 (c 2 (c 13 (c (sha256 60 (sha256 20 24) (sha256 60 (sha256 60 (sha256 20 44) 9) (sha256 60 11 (sha256 20
# ())))) ())))) (q . 11)) 1) 2 46 (c 2 (c 9 (c 0x017fdd (c (sha256 20 -16419) (c (sha256 20 24541) (c (sha256 20
# 12253) (c (sha256 20 21) (c (sha256 20 6109) (c (sha256 20 3037) (c (sha256 20 1501) (c (sha256 20 733) (c (sha256
# 20 349) (c (sha256 20 -99) (c (sha256 20 9) (c (a 62 (c 2 (c 45 ()))) ())))))))))))))))) (a 46 (c 2 (c 9 (c 11 (c
# (a 62 (c 2 (c 5 ()))) ()))))) (sha256 60 (sha256 20 16) (sha256 60 (sha256 60 (sha256 20 44) 5) (sha256 60 (a 18 (c
# 2 (c 7 (c (sha256 20 20) ())))) (sha256 20 ())))) 2 (i (l 5) (q 11 (q . 2) (a 62 (c 2 (c 9 ()))) (a 62 (c 2 (c 13
# ...

# %%
genesis_by_coin_id_or_proposal = load_hex("./genesis_by_coin_id_or_proposal.hex")
genesis_by_coin_id_or_proposal.get_tree_hash().hex()
# Out:
# '2a9bf55320cde17fda5f54678f4e0b4fd5d2d8f193b8f2e1286ff200e647e09e'

# %% [markdown]
# ```
# (
#       GENESIS_ID
#       DAO_TREASURY_ID
#       SINGLETON_MOD_HASH
#       SINGLETON_LAUNCHER_PUZHASH
#       DAO_PROPOSAL_MOD_HASH
#       Truths
#       parent_is_cat
#       lineage_proof
#       delta
#       inner_conditions
#       ( ; solution
#         proposal_curry_vals
#         proposal_id
#       )
# )
# ```
# ```sh
# ## GENESIS_ID
# (0x570f26cc1b8ebbb75dd4a80340db5f1cebfca4fc94831d2ed8cdb3e1645c573f             ## DAO_TREASURY_ID
# 0xa14daf55d41ced6419bcd011fbc1f74ab9567fe55340d88435aa6493d628fa47               ## SINGLETON_MOD_HASH
# 0x7faa3253bfddd1e0decb0906b2dc6247bbc4cf608f58345d173adb63e8b47c9f               ## SINGLETON_LAUNCHER_PUZHASH
# 0xeff07522495060c066f66f32acc2a77e3a3e737aca8baea4d1a64ea4cdc13da9               ## DAO_PROPOSAL_MOD_HASH
# 0xd74c535eaeb4bf9946c5bfa505b02842c4e6ed78fe050bc189aef82e41b39241)
# ```

# %%
p1 = Program.fromhex("...")

# %%
print_program(p1)
# Out:
# (a (q 2 (q 2 (i 11 (q 2 (i (= 5 (point_add 11 (pubkey_for_exp (sha256 11 (a 6 (c 2 (c 23 ()))))))) (q 2 23 47) (q
# 8)) 1) (q 4 (c 4 (c 5 (c (a 6 (c 2 (c 23 ()))) ()))) (a 23 47))) 1) (c (q 50 2 (i (l 5) (q 11 (q . 2) (a 6 (c 2 (c
# 9 ()))) (a 6 (c 2 (c 13 ())))) (q 11 (q . 1) 5)) 1) 1)) (c (q .
# 0x97a9ad6db805dbca4bb1fb8525970fb32d5ed1e7c3a0f3c3a49a4dec536f47d8d4111cb6ffe268910cfe9fa38d5ba50d) 1))

# %%
s1 = Program.fromhex("")
print_program(s1)
# Out:
# (() (q (51 0x1f5a0808a7ebc411c98538d57e1623638f6de31c741842f92e5e16b49ef462ce 200) (51
# 0xe4fb5940aef16e2c6cfed28ea3934dada96f4ce2b629b17cd482eb31f6a6c559 ":5)C8") (60
# 0x5e269000b9f0033e3c9acd0ceef2436d6a2f8ccfbbed67ab097958c025c0da26)) ())

# %%
p2 = Program.fromhex("...")
print_program(p2)
p2.get_tree_hash().hex()
# Out:
# (a (q 2 (q 2 94 (c 2 (c (c 5 (c (sha256 52 5) (c 11 ()))) (c (a 23 47) (c 95 (c (a 46 (c 2 (c 23 ()))) (c (a 42 (c
# 2 (c 639 (c 1407 (c 2943 ()))))) (c -65 (c 383 (c 767 (c 1535 (c 3071 ())))))))))))) (c (q (((61 . 70) 2 51 . 60)
# (c . 1) 1 -53 . 2) ((not 2 (i 5 (q 2 50 (c 2 (c 13 (c (sha256 124 (sha256 52 36) (sha256 124 (sha256 124 (sha256 52
# 44) 9) (sha256 124 11 (sha256 52 ())))) ())))) (q . 11)) 1) (a (i (all (= (strlen 5) 34) (= (strlen 11) 34) (> 23
# (q . -1))) (q 11 5 11 23) (q 8)) 1) (a (i 11 (q 2 (i (= (a 46 (c 2 (c 19 ()))) 2975) (q 2 86 (c 2 (c (a 19 (c 95 (c
# 23 (c 47 (c -65 (c 383 (c 27 ()))))))) (c 383 ())))) (q 8)) 1) (q 2 (i 23 (q 2 (i (not -65) (q . 383) (q 8)) 1) (q
# 8)) 1)) 1) 4 (c 5 39) (c (+ 11 87) 119)) ((a (i 5 (q 2 (i (= (a (i (= 17 88) (q . 89) ()) 1) (q . -113)) (q 2 38 (c
# 2 (c 13 (c 11 (c (c -71 377) ()))))) (q 2 122 (c 2 (c (a (i (= 17 88) (q 4 88 (c (a 118 (c 2 (c 19 (c 41 (c (sha256
# ...

# %%
s2 = Program.fromhex("...")
print_program(s2)
# Out:
# ((() (q (51 0xe25b0ff7a50e4afae386cdab538c70983db7f04fa835b45855114f9d790c414a 200) (51 () -113 (a (q 2 (q 2 (i
# 1535 (q 8) (q 2 (i (= 1471 5) () (q 2 (i (= 1471 (a 22 (c 2 (c (c 23 (c 22527 47)) (c (a 26 (c 2 (c 95 (c 11 (c (c
# 23 (c 22527 47)) (c 10239 ())))))) ()))))) () (q 8)) 1)) 1)) 1) (c (q ((a . 4) 1 1 . 2) ((a (i 5 (q 2 18 (c 2 (c 13
# (c (sha256 60 (sha256 20 24) (sha256 60 (sha256 60 (sha256 20 44) 9) (sha256 60 11 (sha256 20 ())))) ())))) (q .
# 11)) 1) 2 46 (c 2 (c 9 (c 0x017fdd (c (sha256 20 -16419) (c (sha256 20 24541) (c (sha256 20 12253) (c (sha256 20
# 21) (c (sha256 20 6109) (c (sha256 20 3037) (c (sha256 20 1501) (c (sha256 20 733) (c (sha256 20 349) (c (sha256 20
# -99) (c (sha256 20 9) (c (a 62 (c 2 (c 45 ()))) ())))))))))))))))) (a 46 (c 2 (c 9 (c 11 (c (a 62 (c 2 (c 5 ())))
# ()))))) (sha256 60 (sha256 20 16) (sha256 60 (sha256 60 (sha256 20 44) 5) (sha256 60 (a 18 (c 2 (c 7 (c (sha256 20
# ...

# %%
print_conditions(
    p1,
    s1
)
# Out:
# (AGG_SIG_ME 0x97a9ad6db805dbca4bb1fb8525970fb32d5ed1e7c3a0f3c3a49a4dec536f47d8d4111cb6ffe268910cfe9fa38d5ba50d
# 0x9dc0309cddcc23570f87f76e2040fddd0ecedc82bccb0616bd9c56557bc1a9e5)
# (CREATE_COIN 0x1f5a0808a7ebc411c98538d57e1623638f6de31c741842f92e5e16b49ef462ce 200)
# (CREATE_COIN 0xe4fb5940aef16e2c6cfed28ea3934dada96f4ce2b629b17cd482eb31f6a6c559 ":5)C8")
# (CREATE_COIN_ANNOUNCEMENT 0x5e269000b9f0033e3c9acd0ceef2436d6a2f8ccfbbed67ab097958c025c0da26)

# %%
print_conditions(
    p2,
    s2
)
# Out:
# (ASSERT_MY_COIN_ID 0x26b98e14a3712010b27ecd8c69cc99d30287cc639bbf6d9c265cda3fb7ec5241)
# (CREATE_COIN_ANNOUNCEMENT 0xcb2d6ed70da8f3518556b35fbdbe81866e996b36090a816ce68f649b4823c1f730)
# (ASSERT_COIN_ANNOUNCEMENT 0x98dd7fef166d3cad4a26d38aab7c88c571985f524652f10699eb8100aa2c58f3)
# (AGG_SIG_ME 0xa3b0219722055ac0a66cd9de5cd3e86962d8c8ec6abb801b57e5c77ed98453b02ceae0e19548f6d4fc20b3a2ec82aa90
# 0x3d44b439ac92fe5f463ed1e2a0971757210bc3e0dd58e09dd88007f9db4c8f4f)
# (CREATE_COIN 0x1f5a0808a7ebc411c98538d57e1623638f6de31c741842f92e5e16b49ef462ce 200)

# %%
#        dao_treasury_puzzle = get_treasury_puzzle(
#            launcher_coin.name(),
#            cat_tail.get_tree_hash(),
#            amount_of_cats,
#            attendance_required_percentage,
#            proposal_pass_percentage,
#            proposal_timelock,
#        )
tp = Program.fromhex("...")
print_program(tp)
# Out:
# (a (q 2 (q 4 (c (q . 73) (c 11 (q))) (a (i 191 (q 2 (q 4 (c (q . 62) (c 47 (q))) (a 26 (c 2 (c (a (i (= 3071 (q .
# 117)) (q 2 (q 4 (c (q . 51) (c 191 (c (+ 11 23) (c (c (f (r 9)) (q)) (q))))) (c (c (q . 72) (c 191 (q))) (q))) 1)
# (q 2 (q 2 (i (= 3071 (q . 114)) (q 2 (q 4 (c (q . 51) (c (a 20 (c 2 (c 21 (c (a 28 (c 2 (c (a 18 (c 2 (c 191 (c (q)
# (c (c 9 (c 21 (c 45 (c 93 (c 189 (c 381 (c 765 (c 1533 (c 3069 (c 6141 (c 12285 (q)))))))))))) ()))))) ()))) ()))))
# (c (+ 11 23) (c (c (f (r 9)) (q)) (q))))) (q)) 1) (q 2 (q 2 (i (= 3071 (q . 110)) (q 2 (q 2 (i (= 191 (a 28 (c 2 (c
# 6143 ())))) (q 2 (q 4 (c (q . 51) (c 191 (c (+ 11 23) (c (c (f (r 9)) (q)) (q))))) (q)) 1) (q 2 (q 8) 1)) 1) 1) (q
# 2 (q 8) 1)) 1) 1)) 1) 1)) 1) (c (a 30 (c 2 (c 12285 (c (a 20 (c 2 (c (f (c (f 9) (c 47 (r (r 9))))) (c (a 20 (c 2
# (c 45 (c (a 28 (c 2 (c 383 ()))) (c (sha256 (q . 1) 1535) (c (sha256 (q . 1) 767) (c (sha256 (q . 1) (f (r 9))) (c
# ...

# %%
tp_, c_ = tp.uncurry()
print_program(tp_)
print_program(c_)
# Out:
# (a (q 4 (c (q . 73) (c 11 (q))) (a (i 191 (q 2 (q 4 (c (q . 62) (c 47 (q))) (a 26 (c 2 (c (a (i (= 3071 (q . 117))
# (q 2 (q 4 (c (q . 51) (c 191 (c (+ 11 23) (c (c (f (r 9)) (q)) (q))))) (c (c (q . 72) (c 191 (q))) (q))) 1) (q 2 (q
# 2 (i (= 3071 (q . 114)) (q 2 (q 4 (c (q . 51) (c (a 20 (c 2 (c 21 (c (a 28 (c 2 (c (a 18 (c 2 (c 191 (c (q) (c (c 9
# (c 21 (c 45 (c 93 (c 189 (c 381 (c 765 (c 1533 (c 3069 (c 6141 (c 12285 (q)))))))))))) ()))))) ()))) ())))) (c (+
# 11 23) (c (c (f (r 9)) (q)) (q))))) (q)) 1) (q 2 (q 2 (i (= 3071 (q . 110)) (q 2 (q 2 (i (= 191 (a 28 (c 2 (c 6143
# ())))) (q 2 (q 4 (c (q . 51) (c 191 (c (+ 11 23) (c (c (f (r 9)) (q)) (q))))) (q)) 1) (q 2 (q 8) 1)) 1) 1) (q 2 (q
# 8) 1)) 1) 1)) 1) 1)) 1) (c (a 30 (c 2 (c 12285 (c (a 20 (c 2 (c (f (c (f 9) (c 47 (r (r 9))))) (c (a 20 (c 2 (c 45
# (c (a 28 (c 2 (c 383 ()))) (c (sha256 (q . 1) 1535) (c (sha256 (q . 1) 767) (c (sha256 (q . 1) (f (r 9))) (c
# ...

# %%
tp_.get_tree_hash().hex()
# Out:
# 'fed7b7e80075e5cf9a6870e289aaf3950e8676b57454bc21aaf2276c52110206'

# %%
load_hex("./dao_treasury.hex").get_tree_hash().hex()
# Out:
# 'fed7b7e80075e5cf9a6870e289aaf3950e8676b57454bc21aaf2276c52110206'

# %%
#         full_treasury_puzzle = curry_singleton(launcher_coin.name(), dao_treasury_puzzle)

ftp = Program.fromhex("...")
print_program(ftp)
ftp.get_tree_hash().hex()
# Out:
# (a (q 2 (q 2 (i (logand 47 52) (q 4 (c 32 (c 47 ())) (c (a 62 (c 2 (c 5 (c (a 42 (c 2 (c 39 (c (a (i 119 (q 2 54 (c
# 2 (c 9 (c 87 (c (a 46 (c 2 (c 5 ()))) ()))))) (q . 29)) 1) (c (a (i 119 (q . -73) (q . 87)) 1) ()))))) (c 119
# ()))))) (a 58 (c 2 (c 5 (c (a 11 95) (q ()))))))) (q 8)) 1) (c (q (((73 . 71) 2 . 51) (c . 1) 1 . 2) ((not 2 (i 5
# (q 2 50 (c 2 (c 13 (c (sha256 60 (sha256 52 36) (sha256 60 (sha256 60 (sha256 52 44) 9) (sha256 60 11 (sha256 52
# ())))) ())))) (q . 11)) 1) (a (i (all (= (strlen 5) 34) (= (strlen 11) 34) (> 23 (q . -1))) (q 11 5 11 23) (q 8))
# 1) 2 (i 11 (q 2 (i (a 38 (c 2 (c 19 ()))) (q 2 (i (not 23) (q 2 (i (= -77 (q . -113)) (q 2 58 (c 2 (c 5 (c 27 (c 52
# ()))))) (q 4 (c 35 (c (a 54 (c 2 (c 9 (c 83 (c (a 46 (c 2 (c 5 ()))) ()))))) 115)) (a 58 (c 2 (c 5 (c 27 (c 52
# ()))))))) 1) (q 8)) 1) (q 4 19 (a 58 (c 2 (c 5 (c 27 (c 23 ()))))))) 1) (q 2 (i 23 () (q 8)) 1)) 1) ((a (i (= 9 56)
# ...

# %% [markdown]
# ```sh
# # SINGLETON_STRUCT
# (0x7faa3253bfddd1e0decb0906b2dc6247bbc4cf608f58345d173adb63e8b47c9f
# 0xa14daf55d41ced6419bcd011fbc1f74ab9567fe55340d88435aa6493d628fa47 .
# 0xeff07522495060c066f66f32acc2a77e3a3e737aca8baea4d1a64ea4cdc13da9)
#
# # cat_tail
# 0xa73cc4c2163c62d7c928d34f68aa8d6753ad925c5cdfb36d5a23ea1f543e311a
# # current_cat_issuance
# 200
# # attendance_required_percentage
# 10
# # proposal_pass_percentage
# 10
# # proposal_timelock
# 10
# ) 1)))
#
# ```
